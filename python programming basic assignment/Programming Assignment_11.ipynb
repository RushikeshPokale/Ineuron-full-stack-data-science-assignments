# %% [markdown]
# ### 1. Write a Python program to find words which are greater than given length k?

# %%
def greaterthan(sentense):
    words = []
    split = sentense.split(" ")
    print(split)
    k = int(input("Enter length: "))
    for i in split:
        if len(i)>k:
            words.append(i)
    return words

# %%
greaterthan("hello world how are you")
# Out:
# ['hello', 'world', 'how', 'are', 'you']
# Enter length: 3
# ['hello', 'world']

# %% [markdown]
# ### 2. Write a Python program for removing i-th character from a string?

# %%
def remove_char(sentense):
    split = sentense.split(" ")
    i_th = int(input("Enter position: "))
    for i in split:
        if split[i_th]==i:
            split.remove(i)
    sentense = " ".join(split)
    return sentense

# %%
remove_char("hello world this is rushikesh")
# Out:
# Enter position: 2
# 'hello world is rushikesh'

# %% [markdown]
# ### 3. Write a Python program to split and join a string?

# %%
def split_join(sentense):
    split = sentense.split()
    print("Splited sentense: ",split)
    join  = ' '.join(split)
    print("sentense joined is: ",join)

# %%
split_join("My name is rushikesh")
# Out:
# Splited sentense:  ['My', 'name', 'is', 'rushikesh']
# sentense joined is:  My name is rushikesh

# %% [markdown]
# ### 4. Write a Python to check if a given string is binary string or not?

# %%
def binary_check(string):
    arrange = set(string)
    binary = {'0','1'}
    
    if binary == arrange or arrange=={'0'} or arrange == {'1'}:
        print("String is binary")
    else:
        print("String not binary")

# %%
binary_check("101010")
# Out:
# String is binary

# %%
binary_check("hello")
# Out:
# String not binary

# %% [markdown]
# ### 5. Write a Python program to find uncommon words from two Strings?

# %%
string1 = str(input("Enter String: "))
string2 = str(input("Enter String: "))
a = string1.split()
b = string2.split()
print(a,"\n", b)
UC = []
for i in a:
    if i not in b:
        UC.append(i)
for j in b:
    if j not in a:
        UC.append(j)
print(UC)
# Out:
# Enter String: hello world rushikesh
# Enter String: hello world pokale
# ['hello', 'world', 'rushikesh']
#  ['hello', 'world', 'pokale']
# ['rushikesh', 'pokale']

# %% [markdown]
# ### 6. Write a Python to find all duplicate characters in string?

# %%
string = str(input("Enter string:  "))
char = []
duplicate = []
for i in string:
    if i  not in char:
        char.append(i)
    else:
        duplicate.append(i)
print("Duplicate characters are: " ,duplicate)
# Out:
# Enter string:  hello world
# Duplicate characters are:  ['l', 'o', 'l']

# %% [markdown]
# ### 7. Write a Python Program to check if a string contains any special character?

# %%
spl_char = '[@_!#$%^&*()<>?/\|}{~:]'
string = str(input("Enter string: "))

for i in string:
    if i not in spl_char:
        continue
        
    else:
        print("Special Char {} found in given string".format(i))
# Out:
# Enter string: hell@#O
# Special Char @ found in given string
# Special Char # found in given string
